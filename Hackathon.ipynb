# %%
Hackathon

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('DataForTable.csv', index_col=0)

data.head(5)
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2008        3.724               7.350           0.451
# Afghanistan   2009        4.402               7.509           0.552
# Afghanistan   2010        4.758               7.614           0.539
# Afghanistan   2011        3.832               7.581           0.521
# Afghanistan   2012        3.783               7.661           0.521
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                               50.5                         0.718
# Afghanistan                               50.8                         0.679
# Afghanistan                               51.1                         0.600
# Afghanistan                               51.4                         0.496
# Afghanistan                               51.7                         0.531
#
# ...

# %%
countries = [ 'Max : ' + by_year_data['Life Ladder'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Life Ladder'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
life_ladder = [ by_year_data['Life Ladder'].get_group(2022).max(),
by_year_data['Life Ladder'].get_group(2022).min() , by_year_data['Life Ladder'].get_group(2022).mean()
]

fig, ax = plt.subplots()

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Life ladder')
ax.set_title('Life ladder in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=10)
plt.show()



life_ladder1 = pd.cut(by_year_data['Life Ladder'].get_group(2022),
       bins=[0, by_year_data['Life Ladder'].get_group(2022).mean(), 10],
       labels=[0, 1])

print('In 2022,', life_ladder1.value_counts()[1] ,'countries are higher than average' )
# Out:
# In 2022, 67 countries are higher than average

# %%
countries = [ 'Max : ' + by_year_data['Log GDP per capita'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Log GDP per capita'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
y_pos = np.arange(len(countries))
life_ladder = [ by_year_data['Log GDP per capita'].get_group(2022).max(),
by_year_data['Log GDP per capita'].get_group(2022).min() , by_year_data['Log GDP per capita'].get_group(2022).mean()]

fig, ax = plt.subplots(1,1)

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Log GDP per capita')
ax.set_title('Log GDP per capita in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=15)
plt.show()


GDP1 = pd.cut(by_year_data['Log GDP per capita'].get_group(2022),
       bins=[0, by_year_data['Log GDP per capita'].get_group(2022).mean(), 15],
       labels=[0, 1])

print('In 2022,', GDP1.value_counts()[1] ,'countries are higher than average' )
# Out:
# In 2022, 58 countries are higher than average

# %%
countries = [ 'Max : ' + by_year_data['Social support'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Social support'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
y_pos = np.arange(len(countries))
life_ladder = [ by_year_data['Social support'].get_group(2022).max(),
by_year_data['Social support'].get_group(2022).min() , by_year_data['Social support'].get_group(2022).mean()
]

fig, ax = plt.subplots()

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Social support')
ax.set_title('Social support in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=1)
plt.show()



social_support1 = pd.cut(by_year_data['Social support'].get_group(2022),
       bins=[0, by_year_data['Social support'].get_group(2022).mean(), 1],
       labels=['0', '1'])


print('In 2022,', social_support1.value_counts()[1]  ,'countries are higher than average' )
# Out:
# In 2022, 41 countries are higher than average
# /var/folders/s2/j7v7sc5n4vx937pd3fr04_k00000gn/T/ipykernel_37198/312069150.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('In 2022,', social_support1.value_counts()[1]  ,'countries are higher than average' )

# %%
countries = [ 'Max : ' + by_year_data['Healthy life expectancy at birth'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Healthy life expectancy at birth'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
y_pos = np.arange(len(countries))
life_ladder = [ by_year_data['Healthy life expectancy at birth'].get_group(2022).max(),
by_year_data['Healthy life expectancy at birth'].get_group(2022).min() , by_year_data['Healthy life expectancy at birth'].get_group(2022).mean()]

fig, ax = plt.subplots(1,1)

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Healthy life expectancy at birth')
ax.set_title('Healthy life expectancy at birth in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=80)
plt.show()


birth1 = pd.cut(by_year_data['Healthy life expectancy at birth'].get_group(2022),
       bins=[0, by_year_data['Healthy life expectancy at birth'].get_group(2022).mean(), 80],
       labels=[0, 1])

print('In 2022,', birth1.value_counts()[1] ,'countries are higher than average' )
# Out:
# In 2022, 66 countries are higher than average

# %%
countries = [ 'Max : ' + by_year_data['Freedom to make life choices'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Freedom to make life choices'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
y_pos = np.arange(len(countries))
life_ladder = [ by_year_data['Freedom to make life choices'].get_group(2022).max(),
by_year_data['Freedom to make life choices'].get_group(2022).min() , by_year_data['Freedom to make life choices'].get_group(2022).mean()]

fig, ax = plt.subplots(1,1)

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Freedom to make life choices')
ax.set_title('Freedom to make life choices in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=1)
plt.show()


freedom1 = pd.cut(by_year_data['Freedom to make life choices'].get_group(2022),
       bins=[0, by_year_data['Freedom to make life choices'].get_group(2022).mean(), 1],
       labels=[0, 1])

print('In 2022,', freedom1.value_counts()[1] ,'countries are higher than average' )
# Out:
# In 2022, 64 countries are higher than average

# %%
countries = [ 'Max : ' + by_year_data['Generosity'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Generosity'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
y_pos = np.arange(len(countries))
life_ladder = [ by_year_data['Generosity'].get_group(2022).max(),
by_year_data['Generosity'].get_group(2022).min() , by_year_data['Generosity'].get_group(2022).mean()]

fig, ax = plt.subplots(1,1)

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Generosity')
ax.set_title('Generosity in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=0.6, left=(-0.6))
plt.show()


gen1 = pd.cut(by_year_data['Generosity'].get_group(2022),
       bins=[-1, by_year_data['Generosity'].get_group(2022).mean(), 1],
       labels=[0, 1])

print('In 2022,', gen1.value_counts()[1] ,'countries are higher than average' )
# Out:
# In 2022, 47 countries are higher than average

# %%
countries = [ 'Max : ' + by_year_data['Perceptions of corruption'].get_group(2022).sort_values(ascending = False).head(1).index[0]
, 'Min : ' + by_year_data['Perceptions of corruption'].get_group(2022).sort_values().head(1).index[0]
 , 'Mean']
y_pos = np.arange(len(countries))
life_ladder = [ by_year_data['Perceptions of corruption'].get_group(2022).max(),
by_year_data['Perceptions of corruption'].get_group(2022).min() , by_year_data['Perceptions of corruption'].get_group(2022).mean()]

fig, ax = plt.subplots(1,1)

hbars = ax.barh(y_pos, life_ladder, align='center', color = ['springgreen','crimson','darkturquoise'])
ax.set_yticks(y_pos, labels=countries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Perceptions of corruption')
ax.set_title('Perceptions of corruption in 2022')

ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=1)
plt.show()


corr1 = pd.cut(by_year_data['Perceptions of corruption'].get_group(2022),
       bins=[0, by_year_data['Perceptions of corruption'].get_group(2022).mean(), 1],
       labels=[0, 1])

print('In 2022,', corr1.value_counts()[1] ,'countries are higher than average' )
# Out:
# In 2022, 70 countries are higher than average

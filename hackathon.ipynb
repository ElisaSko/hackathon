# %% [markdown]
# #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib.patches as mpatches

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
# groupement par année
by_year = data.groupby('year')
by_year.size()
# Out:
# year
# 2005     27
# 2006     89
# 2007    102
# 2008    110
# 2009    114
# 2010    124
# 2011    146
# 2012    141
# 2013    136
# 2014    144
# 2015    142
# 2016    141
# 2017    147
# 2018    141
# 2019    143
# 2020    116
# 2021    122
# 2022    114
# dtype: int64

# %%
test = by_year.get_group(2022)
test.head()
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 13  Afghanistan  2022        1.281                 NaN           0.228
# 28      Albania  2022        5.212               9.626           0.724
# 59    Argentina  2022        6.261              10.011           0.893
# 75      Armenia  2022        5.382               9.668           0.811
# 91    Australia  2022        7.035              10.854           0.942
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 13                            54.875                         0.368
# 28                            69.175                         0.802
# 59                            67.250                         0.825
# 75                            67.925                         0.790
# 91                            71.125                         0.854
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
pays = test.index
pays
# Out:
# Index([  13,   28,   59,   75,   91,  106,  148,  178,  194,  214,
#        ...
#        1979, 2038, 2053, 2070, 2087, 2104, 2120, 2137, 2154, 2198],
#       dtype='int64', length=114)

# %%
pays = test3['Country name'].unique()
print(pays)
#x = pays

width = 0.25
multiplier = 0

fig, ax1 = plt.subplots(1, 1)
ax2 = ax1.twinx()

#ax.bar(pays, test3[ 'Social support'])
#ax.bar(pays, test3['Social support'])
#for pays, donnee in test3[['Life Ladder', 'Log GDP per capita', 'Social support']].items():
#    rects = ax.bar(x , donnee, width, label = pays)
#    ax.bar_label(rects, padding = 3)
#    multiplier += 1

# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(pays))
for ((attribute, measurement), ax, col) in zip(test3[['Log GDP per capita', 'Social support']].items(), [ax1, ax2], ['blue', 'red']):
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color = col)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax1.set_xticks(x + width, pays)
ax1.legend(loc='upper left', ncols=3)
ax1.set_ylim(0, 12)

ax2.legend(loc='lower left', ncols=3)
ax2.set_ylim(0, 1)



plt.tight_layout()
plt.show();
# Out:
# ['Afghanistan' 'Albania' 'Argentina' 'Armenia' 'Australia' 'Austria']

# %%
afg = data[data['Country name'] == 'Afghanistan']
fig, ax = plt.subplots()
plt.plot(afg['year'], afg['Life Ladder'])
plt.plot(afg['year'], afg['Log GDP per capita'])
plt.plot(afg['year'], afg['Social support'])
plt.plot(afg['year'], afg['Freedom to make life choices'])
plt.title('Afghanistan')

LL= mpatches.Patch(color='blue', label='Life Ladder')
GDP = mpatches.Patch(color='orange', label='Log GDP per capita')
SS = mpatches.Patch(color='red', label='Social Support')
F = mpatches.Patch(color='green', label='Freedom to make life choices')
ax.legend(handles=[LL, GDP, SS, F])
plt.tight_layout()
plt.plot()

rus = data[data['Country name'] == 'Russia']
fig, ax = plt.subplots()
plt.plot(rus['year'], rus['Life Ladder'])
plt.plot(rus['year'], rus['Log GDP per capita'])
plt.plot(rus['year'], rus['Social support'])
plt.plot(rus['year'], rus['Freedom to make life choices'])
plt.title('Russia')

LL= mpatches.Patch(color='blue', label='Life Ladder')
GDP = mpatches.Patch(color='orange', label='Log GDP per capita')
SS = mpatches.Patch(color='red', label='Social Support')
F = mpatches.Patch(color='green', label='Freedom to make life choices')
ax.legend(handles=[LL, GDP, SS, F])

plt.tight_layout()
plt.plot()

ch = data[data['Country name'] == 'China']
fig, ax = plt.subplots()
plt.plot(ch['year'], ch['Life Ladder'])
plt.plot(ch['year'], ch['Log GDP per capita'])
plt.plot(afg['year'], afg['Social support'])
plt.plot(afg['year'], afg['Freedom to make life choices'])
plt.title('Chine')

LL= mpatches.Patch(color='blue', label='Life Ladder')
GDP = mpatches.Patch(color='orange', label='Log GDP per capita')
SS = mpatches.Patch(color='red', label='Social Support')
F = mpatches.Patch(color='green', label='Freedom to make life choices')
ax.legend(handles=[LL, GDP, SS, F])

plt.tight_layout()
plt.plot()


fr = data[data['Country name'] == 'France']
fig, ax = plt.subplots()
ax.set_xlim(2005, 2022)
plt.plot(fr['year'], fr['Life Ladder'])
plt.plot(fr['year'], fr['Log GDP per capita'])
plt.title('France')

LL= mpatches.Patch(color='blue', label='Life Ladder')
GDP = mpatches.Patch(color='orange', label='Log GDP per capita')
SS = mpatches.Patch(color='red', label='Social Support')
F = mpatches.Patch(color='green', label='Freedom to make life choices')
ax.legend(handles=[LL, GDP, SS, F])

plt.tight_layout();

# %%
fr
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 638       France  2005        7.093              10.637           0.940
# 639       France  2006        6.583              10.654           0.944
# 640       France  2008        7.008              10.669           0.935
# 641       France  2009        6.283              10.635           0.918
# 642       France  2010        6.798              10.649           0.943
# 643       France  2011        6.959              10.666           0.921
# 644       France  2012        6.649              10.664           0.937
# 645       France  2013        6.667              10.665           0.908
# 646       France  2014        6.467              10.669           0.878
# 647       France  2015        6.358              10.677           0.896
# 648       France  2016        6.475              10.685           0.885
# 649       France  2017        6.635              10.705           0.931
# ...
